# %% [markdown]
# In this notebook, we'll use the Blankly package to gather data and backtest a machine learning model. We'll use PyTorch for the model itself, and the model will be an LSTM (Long Short-Term Memory) recursive neural network. LSTMs are great for sequential data, as their architecture allows them to uncover relationships in data while taking into account the significance of the order in which data comes. Once we have the model, we'll use its predictions to decide how much Ethereum to buy or sell on any given day.

# %%
# !pip install blankly #install blankly

# %% [markdown]
# We'll initialize the basics of our Blankly environment with the command '*blankly init*'. Once done, we get template .json files that we'll need for configuring backtests. Most importantly, we'll need to input our API keys into keys.json.

# %%
# !blankly init
# Out:
# Initializing...
#
# ██████╗ ██╗      █████╗ ███╗   ██╗██╗  ██╗██╗  ██╗   ██╗    ███████╗██╗███╗   ██╗ █████╗ ███╗   ██╗ ██████╗███████╗
# ██╔══██╗██║     ██╔══██╗████╗  ██║██║ ██╔╝██║  ╚██╗ ██╔╝    ██╔════╝██║████╗  ██║██╔══██╗████╗  ██║██╔════╝██╔════╝
# ██████╔╝██║     ███████║██╔██╗ ██║█████╔╝ ██║   ╚████╔╝     █████╗  ██║██╔██╗ ██║███████║██╔██╗ ██║██║     █████╗
# ██╔══██╗██║     ██╔══██║██║╚██╗██║██╔═██╗ ██║    ╚██╔╝      ██╔══╝  ██║██║╚██╗██║██╔══██║██║╚██╗██║██║     ██╔══╝
# ██████╔╝███████╗██║  ██║██║ ╚████║██║  ██╗███████╗██║       ██║     ██║██║ ╚████║██║  ██║██║ ╚████║╚██████╗███████╗
# ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═╝  ╚═══╝╚═╝  ╚═╝╚══════╝╚═╝       ╚═╝     ╚═╝╚═╝  ╚═══╝╚═╝  ╚═╝╚═╝  ╚═══╝ ╚═════╝╚══════╝
#
# Downloading keys template...
# Downloading settings defaults...
# Downloading backtest defaults...
# Downloading RSI bot example...
# Writing deployment defaults...
# Detecting python version...
# Found python version: 3.7
# Writing requirements.txt defaults...
# Success!

# %%
import blankly
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import LSTM
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import random_split

# %% [markdown]
# PyTorch has basically any ML building block you could want.

# %%
def episode_gen(data, seq_length,output_size):
    x = []
    y = []
    #Loop through data, adding input data to x array and output data to y array
    for i in range(len(data)-seq_length):
        _x = data[i:(i+seq_length - output_size)]
        _y = data[i+seq_length - output_size:i + seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

# %% [markdown]
# We use this method to generate "episodes" for our model to learn from. We have Ethereum prices from the past few years, but the prices that most affect tomorrow's prices are the prices from today and the last few days. As such, we can take "episodes" of length *seq_length* and split them into one section that we want to predict from the other

# %%
def init_NN(symbol, state: blankly.StrategyState):
    interface = state.interface
    resolution = state.resolution
    variables = state.variables

    #Get price data
    variables['history'] = interface.history(symbol, 300, resolution, return_as='list')['close']
    '''We use Blankly's built-in indicator functions to calculate
    indicators we can use along with price data to predict future prices
    '''
    rsi = blankly.indicators.rsi(state.variables['history'])
    macd = blankly.indicators.macd(state.variables['history'])

    '''We'll break the historical Ethereum data into 8 day episodes
    and attempt to predict the final three days using the first 5.
    '''
    seq_length = 8
    output_size = 3

    '''Feature engineering -- here, we calculate the price change from the day before
    as a ratio. This is useful because it means we have less issues with scaling with the model,
    as the data will all already be in roughly the same range. We ignore the first 25 elements
    because we want every observation to have corresponding RSI + MACD data, and MACD requires
    26 periods.
    '''
    x = [variables['history'][i] / variables['history'][i-1] for i in range(25,len(variables['history']))]
    x, y = episode_gen(x, seq_length, output_size)
    y = Variable(torch.Tensor(np.array(y))).unsqueeze(0)
    #RSI data gathering
    x_rsi = rsi[11:]
    x_rsi,_ = episode_gen(x_rsi,seq_length, output_size)

    #MACD data gathering
    macd_vals,_ = episode_gen(macd[0], seq_length, output_size)
    macd_signals,_ = episode_gen(macd[1],seq_length, output_size)

    '''In this section, we put all the features we just extracted into one NumPy array
    which we then convert to a PyTorch tensor that we can run our model on.
    '''
    x_agg = np.zeros((len(macd_signals),seq_length-output_size, 4))
    for i in range(len(macd_signals)):
      for j in range(seq_length - output_size):
        x_agg[i][j][0] = x[i][j]
        x_agg[i][j][1] = x_rsi[i][j]
        x_agg[i][j][2] = macd_vals[i][j]
        x_agg[i][j][3] = macd_signals[i][j]
    x_tot = Variable(torch.Tensor(x_agg))
    '''Here's our training loop! We have a fairly small dataset, so we can run through 10,000 epochs pretty quickly
    Here's also the first place we see our model architecture. We use an LSTM that takes in 4 features and has 
    a hidden state with dimension 20 and feed the hidden state into a linear neural network layer and sigmoid 
    activation that output 3 numbers, the predicted prices for the next three days. We use mean-squared-error loss
    and an Adam optimizer
    '''
    num_epochs = 10000
    learning_rate = 0.0003


    state.lstm = LSTM(4,20, batch_first = True)
    state.lin = nn.Linear(20,3)
    criterion = torch.nn.MSELoss()    # mean-squared error for regression
    #Optimizer: make sure to include parameters of both linear layer and LSTM
    optimizer = torch.optim.Adam([
                {'params': state.lstm.parameters()},
                {'params': state.lin.parameters()}
            ], lr=learning_rate)

    # Train the model
    for epoch in range(num_epochs):
        #run model
        outputs, (h_n, c_n) = state.lstm(x_tot)
        out = state.lin(h_n)
        out = 0.5 + F.sigmoid(out)
        optimizer.zero_grad()
        
        loss = criterion(out, y) #calculate loss function
        
        loss.backward() #backprop
        
        optimizer.step() #gradient descent

        #Output loss functions every 500 epochs so we can make sure the model is training
        if epoch % 500 == 0:
          print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
    #state.lstm.load_state_dict(torch.load('lstm_pm.pth'))
    #state.lin.load_state_dict(torch.load('lin_pm.pth'))      
    '''We use this in the trading algorithm for more stability.
    Essentially, instead of relying on a single output of the model 
    to tell us whether to buy or sell, we average the readings from three different calculations
    (3 days before, 2 days before, day before)
    '''    
    state.lastthree = [[0,0],[0,0],[0,0]]

# %% [markdown]
# This section is where we do the bulk of the work with our data and model. We pull the data using Blankly and calculate values of indicators using Blankly's built in functions. Then, we aggregate the data, instantiate our model (an LSTM that feeds into a linear layer with sigmoid activation), and train the model. We also introduce one of the aspects of the trading algorithm -- the three-day-average for deciding whether to buy or sell (and what amount).

# %%
def price_lstm(price,symbol,state: blankly.StrategyState):
    state.variables['history'].append(price) #Add latest price to current list of data

    '''Here, we pull the data from the last few days, prepare it,
    and run the necessary indicator functions to feed into our model
    '''
    into = [state.variables['history'][i]/state.variables['history'][i-1] for i in range(-5,0)]
    rsi = blankly.indicators.rsi(state.variables['history'])
    rsi_in = np.array(rsi[-5:])
    macd = blankly.indicators.macd(state.variables['history'])
    macd_vals = np.array(macd[0][-5:])
    macd_signals = np.array(macd[1][-5:])

    '''We put the data into the torch Tensor that we'll run the model on
    '''
    pred_in = np.zeros((1,len(into),4))
    for i in range(len(into)):
      pred_in[0][i][0] = into[i]
      pred_in[0][i][1] = rsi_in[i]
      pred_in[0][i][2] = macd_vals[i]
      pred_in[0][i][3] = macd_signals[i]
    pred_in = torch.Tensor(pred_in)
  
    print(price) #Print the price so we can see what's going on

    '''Run the data through the trained model. 
    The field out stores the prediction values we want
    '''
    out,(h,c) = state.lstm(pred_in)
    out = state.lin(h)
    out = 0.5 + F.sigmoid(out)
    
    '''This definitely could be shortened with a loop,
    but basically, we add the percentage increase to the other values in the
    3-day-average array. We also increment a counter showing how many values have been
    added before averaging. This handles the edge case of the first few values (where
    we wouldn't divide by 3)
    '''
    state.lastthree[0][0]+=out[0][0][0]
    state.lastthree[0][1]+=1
    state.lastthree[1][0]+=out[0][0][1]
    state.lastthree[1][1]+=1
    state.lastthree[2][0]+=out[0][0][2]
    state.lastthree[2][1]+=1

    '''The avg price increase is calculated by dividing the sum of next day predictions
    by the number of predictions for the next day.
    '''
    priceavg = state.lastthree[0][0]/state.lastthree[0][1]

    curr_value = blankly.trunc(state.interface.account[state.base_asset].available, 2) #Amount of Ethereum available
    if priceavg > 1:
        # If we think price will increase, we buy
        buy = blankly.trunc(state.interface.cash  * 2 * (priceavg.item() - 1)/price, 2) #Buy an amount proportional to priceavg - 1
        if buy > 0:
          state.interface.market_order(symbol, side='buy', size=buy)
    elif curr_value > 0:
        #If we think price will decrease, we sell
         cv =  blankly.trunc(curr_value  * 2 * (1 - priceavg.item()),2) #Sell an amount proportional to 1 - priceavg
         if cv > 0:
          state.interface.market_order(symbol, side='sell', size=cv)

    print("prediction for price --",priceavg) #Print so we can see what's happening
    state.lastthree = [state.lastthree[1], state.lastthree[2], [0,0]] #Shift the values in our 3-day-average array

# %% [markdown]
# This section is where we implement the logic of the trading algorithm. After we train the model, we still have to decide how to interpret its predictions. We use the average-of-3 method discussed above, where we average the price predictions across 3 days to decide whether to buy or sell. We also vary the amount bought or sold based on the output prediction value -- higher value means more confident buy and lower means more confident sell, so we would buy more if the model output 1.05 than if it output 1.01. Similarly, if the model output 0.95, we would sell more than if it output 0.99.

# %%
exchange = blankly.FTX() #Connect to FTX API
strategy = blankly.Strategy(exchange) #Initialize a Blankly strategy
strategy.add_price_event(price_lstm, symbol='ETH-USD', resolution='1d', init=init_NN) #Add our price event and initialization
results = strategy.backtest(to='1y', initial_values={'USD': 10000}) #Backtest one year starting with $10,000
print(results)
# Out:
# INFO: No portfolio name to load specified, defaulting to the first in the file: (portfolio). This is fine if there is only one portfolio in use.
# Initializing...
# dims:x (266, 5) y (266, 3)
# dims:x_rsi (277, 5)
# dims:macd_vals (266, 5)
# xtot torch.Size([266, 5, 4])
# Epoch: 0, loss: 0.00655
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 500, loss: 0.00223
# Epoch: 1000, loss: 0.00198
# Epoch: 1500, loss: 0.00175
# Epoch: 2000, loss: 0.00157
# Epoch: 2500, loss: 0.00143
# Epoch: 3000, loss: 0.00130
# Epoch: 3500, loss: 0.00118
# Epoch: 4000, loss: 0.00108
# Epoch: 4500, loss: 0.00098
# Epoch: 5000, loss: 0.00088
# Epoch: 5500, loss: 0.00077
# Epoch: 6000, loss: 0.00069
# Epoch: 6500, loss: 0.00062
# Epoch: 7000, loss: 0.00055
# Epoch: 7500, loss: 0.00050
# Epoch: 8000, loss: 0.00047
# Epoch: 8500, loss: 0.00043
# Epoch: 9000, loss: 0.00041
# Epoch: 9500, loss: 0.00038
#
# Backtesting...
# Progress: [----------] 0.0% 1833.2
# prediction for price -- tensor(0.9856, grad_fn=<DivBackward0>)
# 1869.1
# prediction for price -- tensor(0.8249, grad_fn=<DivBackward0>)
# 1797.2
# prediction for price -- tensor(1.2415, grad_fn=<DivBackward0>)
# 1827.7
# prediction for price -- tensor(1.0498, grad_fn=<DivBackward0>)
# 1765.6
# prediction for price -- tensor(1.1630, grad_fn=<DivBackward0>)
# 1923.3
# prediction for price -- tensor(1.2869, grad_fn=<DivBackward0>)
# 1848.8
# prediction for price -- tensor(1.2177, grad_fn=<DivBackward0>)
# 1792.5
# prediction for price -- tensor(1.2171, grad_fn=<DivBackward0>)
# 1806.6
# prediction for price -- tensor(1.1269, grad_fn=<DivBackward0>)
# 1822.1
# prediction for price -- tensor(1.1043, grad_fn=<DivBackward0>)
# 1775.9
# prediction for price -- tensor(1.1112, grad_fn=<DivBackward0>)
# 1809.6
# prediction for price -- tensor(1.1142, grad_fn=<DivBackward0>)
# 1804.7
# prediction for price -- tensor(1.1165, grad_fn=<DivBackward0>)
# 1785.7
# prediction for price -- tensor(1.1247, grad_fn=<DivBackward0>)
# 1681.7
# prediction for price -- tensor(1.1377, grad_fn=<DivBackward0>)
# 1668.8
# prediction for price -- tensor(1.1204, grad_fn=<DivBackward0>)
# 1582.0
# prediction for price -- tensor(1.1001, grad_fn=<DivBackward0>)
# 1586.4
# prediction for price -- tensor(1.0706, grad_fn=<DivBackward0>)
# 1701.2
# prediction for price -- tensor(0.7071, grad_fn=<DivBackward0>)
# 1713.5
# prediction for price -- tensor(1.1149, grad_fn=<DivBackward0>)
# 1686.2
# prediction for price -- tensor(1.0908, grad_fn=<DivBackward0>)
# 1818.2
# prediction for price -- tensor(1.0236, grad_fn=<DivBackward0>)
# 1842.7
# prediction for price -- tensor(1.1731, grad_fn=<DivBackward0>)
# 1920.0
# prediction for price -- tensor(0.8824, grad_fn=<DivBackward0>)
# 1969.0
# prediction for price -- tensor(0.9086, grad_fn=<DivBackward0>)
# 2135.4
# prediction for price -- tensor(1.0695, grad_fn=<DivBackward0>)
# 2009.5
# prediction for price -- tensor(1.3017, grad_fn=<DivBackward0>)
# 2077.5
# prediction for price -- tensor(1.2734, grad_fn=<DivBackward0>)
# 2106.7
# prediction for price -- tensor(1.2273, grad_fn=<DivBackward0>)
# 2114.5
# prediction for price -- tensor(1.1627, grad_fn=<DivBackward0>)
# 1959.7
# prediction for price -- tensor(1.1216, grad_fn=<DivBackward0>)
# 2081.7
# prediction for price -- tensor(1.0740, grad_fn=<DivBackward0>)
# 2064.9
# prediction for price -- tensor(1.0503, grad_fn=<DivBackward0>)
# 2135.4
# prediction for price -- tensor(1.0222, grad_fn=<DivBackward0>)
# 2149.2
# prediction for price -- tensor(1.0295, grad_fn=<DivBackward0>)
# 2137.1
# prediction for price -- tensor(1.0189, grad_fn=<DivBackward0>)
# 2301.1
# prediction for price -- tensor(0.9991, grad_fn=<DivBackward0>)
# 2431.4
# prediction for price -- tensor(1.0205, grad_fn=<DivBackward0>)
# 2519.1
# prediction for price -- tensor(0.9657, grad_fn=<DivBackward0>)
# 2427.1
# prediction for price -- tensor(1.0156, grad_fn=<DivBackward0>)
# 2314.4
# prediction for price -- tensor(0.9400, grad_fn=<DivBackward0>)
# 2243.8
# prediction for price -- tensor(1.1015, grad_fn=<DivBackward0>)
# 2161.9
# prediction for price -- tensor(0.9667, grad_fn=<DivBackward0>)
# 2334.0
# prediction for price -- tensor(1.0507, grad_fn=<DivBackward0>)
# 2360.0
# prediction for price -- tensor(1.0191, grad_fn=<DivBackward0>)
# 2401.9
# prediction for price -- tensor(0.9526, grad_fn=<DivBackward0>)
# 2367.4
# prediction for price -- tensor(0.9239, grad_fn=<DivBackward0>)
# 2215.1
# prediction for price -- tensor(1.0443, grad_fn=<DivBackward0>)
# 2323.7
# prediction for price -- tensor(0.9478, grad_fn=<DivBackward0>)
# 2537.0
# prediction for price -- tensor(0.9495, grad_fn=<DivBackward0>)
# 2670.8
# prediction for price -- tensor(0.9473, grad_fn=<DivBackward0>)
# 2750.9
# prediction for price -- tensor(0.9723, grad_fn=<DivBackward0>)
# 2758.9
# prediction for price -- tensor(1.0122, grad_fn=<DivBackward0>)
# 2777.4
# prediction for price -- tensor(0.9641, grad_fn=<DivBackward0>)
# 2949.0
# prediction for price -- tensor(1.0398, grad_fn=<DivBackward0>)
# 2952.3
# prediction for price -- tensor(0.9496, grad_fn=<DivBackward0>)
# 3428.4
# prediction for price -- tensor(0.9629, grad_fn=<DivBackward0>)
# 3239.5
# prediction for price -- tensor(0.9687, grad_fn=<DivBackward0>)
# 3527.9
# prediction for price -- tensor(0.9413, grad_fn=<DivBackward0>)
# 3490.6
# prediction for price -- tensor(0.9581, grad_fn=<DivBackward0>)
# 3484.9
# prediction for price -- tensor(0.9527, grad_fn=<DivBackward0>)
# 3915.0
# prediction for price -- tensor(0.9458, grad_fn=<DivBackward0>)
# 3930.1
# prediction for price -- tensor(0.9504, grad_fn=<DivBackward0>)
# 3954.2
# prediction for price -- tensor(0.9470, grad_fn=<DivBackward0>)
# 4176.9
# prediction for price -- tensor(0.9469, grad_fn=<DivBackward0>)
# 3818.2
# prediction for price -- tensor(0.9540, grad_fn=<DivBackward0>)
# 3718.6
# prediction for price -- tensor(0.9522, grad_fn=<DivBackward0>)
# 4080.4
# prediction for price -- tensor(0.9501, grad_fn=<DivBackward0>)
# 3643.0
# prediction for price -- tensor(0.9647, grad_fn=<DivBackward0>)
# 3583.5
# prediction for price -- tensor(0.9522, grad_fn=<DivBackward0>)
# 3283.2
# prediction for price -- tensor(0.9516, grad_fn=<DivBackward0>)
# 3378.0
# prediction for price -- tensor(0.9520, grad_fn=<DivBackward0>)
# 2446.8
# prediction for price -- tensor(0.9732, grad_fn=<DivBackward0>)
# 2771.6
# prediction for price -- tensor(0.9830, grad_fn=<DivBackward0>)
# 2436.0
# prediction for price -- tensor(1.0621, grad_fn=<DivBackward0>)
# 2298.9
# prediction for price -- tensor(1.0432, grad_fn=<DivBackward0>)
# 2101.3
# prediction for price -- tensor(1.2486, grad_fn=<DivBackward0>)
# 2650.3
# prediction for price -- tensor(1.0183, grad_fn=<DivBackward0>)
# 2706.2
# prediction for price -- tensor(0.9766, grad_fn=<DivBackward0>)
# 2889.7
# prediction for price -- tensor(0.9901, grad_fn=<DivBackward0>)
# 2743.2
# prediction for price -- tensor(1.0669, grad_fn=<DivBackward0>)
# 2414.3
# prediction for price -- tensor(0.9356, grad_fn=<DivBackward0>)
# 2279.2
# prediction for price -- tensor(0.9054, grad_fn=<DivBackward0>)
# 2387.9
# prediction for price -- tensor(0.9058, grad_fn=<DivBackward0>)
# 2708.3
# prediction for price -- tensor(0.8989, grad_fn=<DivBackward0>)
# 2633.6
# prediction for price -- tensor(0.9294, grad_fn=<DivBackward0>)
# 2707.0
# prediction for price -- tensor(0.8648, grad_fn=<DivBackward0>)
# 2856.1
# prediction for price -- tensor(0.8702, grad_fn=<DivBackward0>)
# 2689.8
# prediction for price -- tensor(0.9072, grad_fn=<DivBackward0>)
# 2628.0
# prediction for price -- tensor(0.9357, grad_fn=<DivBackward0>)
# 2712.9
# prediction for price -- tensor(0.8640, grad_fn=<DivBackward0>)
# 2591.7
# prediction for price -- tensor(0.8633, grad_fn=<DivBackward0>)
# 2510.2
# prediction for price -- tensor(0.8609, grad_fn=<DivBackward0>)
# 2612.8
# prediction for price -- tensor(0.8606, grad_fn=<DivBackward0>)
# 2471.0
# prediction for price -- tensor(0.8624, grad_fn=<DivBackward0>)
# 2353.4
# prediction for price -- tensor(0.8615, grad_fn=<DivBackward0>)
# 2370.1
# prediction for price -- tensor(0.8616, grad_fn=<DivBackward0>)
# 2510.4
# prediction for price -- tensor(0.8614, grad_fn=<DivBackward0>)
# 2581.3
# prediction for price -- tensor(0.8626, grad_fn=<DivBackward0>)
# 2544.3
# prediction for price -- tensor(0.8630, grad_fn=<DivBackward0>)
# Progress: [###-------] 27.55% 2368.7
# prediction for price -- tensor(0.8628, grad_fn=<DivBackward0>)
# 2373.2
# prediction for price -- tensor(0.8609, grad_fn=<DivBackward0>)
# 2233.8
# prediction for price -- tensor(0.8622, grad_fn=<DivBackward0>)
# 2166.9
# prediction for price -- tensor(0.8627, grad_fn=<DivBackward0>)
# 2241.9
# prediction for price -- tensor(0.8618, grad_fn=<DivBackward0>)
# 1887.6
# prediction for price -- tensor(0.8853, grad_fn=<DivBackward0>)
# 1878.2
# prediction for price -- tensor(0.9025, grad_fn=<DivBackward0>)
# 1967.0
# prediction for price -- tensor(0.9421, grad_fn=<DivBackward0>)
# 1989.0
# prediction for price -- tensor(1.0140, grad_fn=<DivBackward0>)
# 1809.6
# prediction for price -- tensor(1.0256, grad_fn=<DivBackward0>)
# 1830.4
# prediction for price -- tensor(1.0725, grad_fn=<DivBackward0>)
# 1983.0
# prediction for price -- tensor(1.0619, grad_fn=<DivBackward0>)
# 2083.4
# prediction for price -- tensor(1.0384, grad_fn=<DivBackward0>)
# 2165.0
# prediction for price -- tensor(1.0293, grad_fn=<DivBackward0>)
# 2275.8
# prediction for price -- tensor(0.9873, grad_fn=<DivBackward0>)
# 2107.7
# prediction for price -- tensor(1.0047, grad_fn=<DivBackward0>)
# 2155.9
# prediction for price -- tensor(0.9945, grad_fn=<DivBackward0>)
# 2228.5
# prediction for price -- tensor(0.8747, grad_fn=<DivBackward0>)
# 2323.6
# prediction for price -- tensor(0.8741, grad_fn=<DivBackward0>)
# 2197.7
# prediction for price -- tensor(0.8616, grad_fn=<DivBackward0>)
# 2322.9
# prediction for price -- tensor(0.8556, grad_fn=<DivBackward0>)
# 2317.8
# prediction for price -- tensor(0.8526, grad_fn=<DivBackward0>)
# 2115.2
# prediction for price -- tensor(0.8531, grad_fn=<DivBackward0>)
# 2146.1
# prediction for price -- tensor(0.8497, grad_fn=<DivBackward0>)
# 2110.9
# prediction for price -- tensor(0.8542, grad_fn=<DivBackward0>)
# 2140.5
# prediction for price -- tensor(0.8609, grad_fn=<DivBackward0>)
# 2031.8
# prediction for price -- tensor(0.8616, grad_fn=<DivBackward0>)
# 1940.9
# prediction for price -- tensor(0.8638, grad_fn=<DivBackward0>)
# 1994.7
# prediction for price -- tensor(0.8587, grad_fn=<DivBackward0>)
# 1918.8
# prediction for price -- tensor(0.8463, grad_fn=<DivBackward0>)
# 1877.8
# prediction for price -- tensor(0.8468, grad_fn=<DivBackward0>)
# 1900.2
# prediction for price -- tensor(0.8604, grad_fn=<DivBackward0>)
# 1891.7
# prediction for price -- tensor(0.8635, grad_fn=<DivBackward0>)
# 1819.1
# prediction for price -- tensor(0.8644, grad_fn=<DivBackward0>)
# 1786.8
# prediction for price -- tensor(0.8638, grad_fn=<DivBackward0>)
# 1996.7
# prediction for price -- tensor(0.8616, grad_fn=<DivBackward0>)
# 2025.0
# prediction for price -- tensor(0.8642, grad_fn=<DivBackward0>)
# 2124.3
# prediction for price -- tensor(0.8623, grad_fn=<DivBackward0>)
# 2188.2
# prediction for price -- tensor(0.8581, grad_fn=<DivBackward0>)
# 2191.1
# prediction for price -- tensor(0.8680, grad_fn=<DivBackward0>)
# 2229.6
# prediction for price -- tensor(0.8654, grad_fn=<DivBackward0>)
# 2300.1
# prediction for price -- tensor(0.8675, grad_fn=<DivBackward0>)
# 2300.4
# prediction for price -- tensor(0.8499, grad_fn=<DivBackward0>)
# 2383.2
# prediction for price -- tensor(0.8596, grad_fn=<DivBackward0>)
# 2462.1
# prediction for price -- tensor(0.9230, grad_fn=<DivBackward0>)
# 2531.9
# prediction for price -- tensor(1.0117, grad_fn=<DivBackward0>)
# 2556.0
# prediction for price -- tensor(1.1110, grad_fn=<DivBackward0>)
# 2607.9
# prediction for price -- tensor(1.1208, grad_fn=<DivBackward0>)
# 2508.0
# prediction for price -- tensor(1.1499, grad_fn=<DivBackward0>)
# 2724.4
# prediction for price -- tensor(1.1394, grad_fn=<DivBackward0>)
# 2829.2
# prediction for price -- tensor(1.1200, grad_fn=<DivBackward0>)
# 2892.3
# prediction for price -- tensor(0.9613, grad_fn=<DivBackward0>)
# 3166.8
# prediction for price -- tensor(0.9529, grad_fn=<DivBackward0>)
# 3012.9
# prediction for price -- tensor(0.8774, grad_fn=<DivBackward0>)
# 3162.7
# prediction for price -- tensor(0.9773, grad_fn=<DivBackward0>)
# 3140.4
# prediction for price -- tensor(0.9631, grad_fn=<DivBackward0>)
# 3164.0
# prediction for price -- tensor(0.9668, grad_fn=<DivBackward0>)
# 3046.3
# prediction for price -- tensor(0.9730, grad_fn=<DivBackward0>)
# 3324.8
# prediction for price -- tensor(0.9573, grad_fn=<DivBackward0>)
# 3266.0
# prediction for price -- tensor(0.9750, grad_fn=<DivBackward0>)
# 3310.3
# prediction for price -- tensor(0.9620, grad_fn=<DivBackward0>)
# 3148.2
# prediction for price -- tensor(0.9798, grad_fn=<DivBackward0>)
# 3013.2
# prediction for price -- tensor(0.9805, grad_fn=<DivBackward0>)
# 3012.6
# prediction for price -- tensor(0.9829, grad_fn=<DivBackward0>)
# 3185.5
# prediction for price -- tensor(0.9665, grad_fn=<DivBackward0>)
# 3286.4
# prediction for price -- tensor(0.9535, grad_fn=<DivBackward0>)
# 3226.6
# prediction for price -- tensor(0.9521, grad_fn=<DivBackward0>)
# 3241.3
# prediction for price -- tensor(0.9482, grad_fn=<DivBackward0>)
# 3321.2
# prediction for price -- tensor(0.9467, grad_fn=<DivBackward0>)
# 3173.2
# prediction for price -- tensor(0.9454, grad_fn=<DivBackward0>)
# 3228.1
# prediction for price -- tensor(0.9472, grad_fn=<DivBackward0>)
# 3091.9
# prediction for price -- tensor(0.9481, grad_fn=<DivBackward0>)
# 3276.1
# prediction for price -- tensor(0.9480, grad_fn=<DivBackward0>)
# 3247.6
# prediction for price -- tensor(0.9452, grad_fn=<DivBackward0>)
# 3225.6
# prediction for price -- tensor(0.9449, grad_fn=<DivBackward0>)
# 3229.1
# prediction for price -- tensor(0.9485, grad_fn=<DivBackward0>)
# 3432.0
# prediction for price -- tensor(0.9389, grad_fn=<DivBackward0>)
# 3830.2
# prediction for price -- tensor(0.9042, grad_fn=<DivBackward0>)
# 3787.4
# prediction for price -- tensor(0.9710, grad_fn=<DivBackward0>)
# 3941.0
# prediction for price -- tensor(0.9580, grad_fn=<DivBackward0>)
# 3889.2
# prediction for price -- tensor(0.9636, grad_fn=<DivBackward0>)
# 3953.3
# prediction for price -- tensor(0.9665, grad_fn=<DivBackward0>)
# 3927.7
# prediction for price -- tensor(0.9702, grad_fn=<DivBackward0>)
# 3433.7
# prediction for price -- tensor(0.9976, grad_fn=<DivBackward0>)
# 3498.8
# prediction for price -- tensor(0.9820, grad_fn=<DivBackward0>)
# 3423.2
# prediction for price -- tensor(1.0175, grad_fn=<DivBackward0>)
# 3208.4
# prediction for price -- tensor(1.0015, grad_fn=<DivBackward0>)
# 3266.7
# prediction for price -- tensor(0.9603, grad_fn=<DivBackward0>)
# 3405.5
# prediction for price -- tensor(0.9591, grad_fn=<DivBackward0>)
# 3284.3
# prediction for price -- tensor(0.9156, grad_fn=<DivBackward0>)
# 3437.2
# prediction for price -- tensor(0.9197, grad_fn=<DivBackward0>)
# 3617.0
# prediction for price -- tensor(1.0197, grad_fn=<DivBackward0>)
# 3568.6
# prediction for price -- tensor(0.9286, grad_fn=<DivBackward0>)
# 3398.0
# prediction for price -- tensor(0.9537, grad_fn=<DivBackward0>)
# 3436.2
# prediction for price -- tensor(0.9628, grad_fn=<DivBackward0>)
# 3329.2
# prediction for price -- tensor(0.9588, grad_fn=<DivBackward0>)
# 2976.6
# prediction for price -- tensor(0.9819, grad_fn=<DivBackward0>)
# 2764.0
# prediction for price -- tensor(1.0658, grad_fn=<DivBackward0>)
# 3079.5
# prediction for price -- tensor(0.8777, grad_fn=<DivBackward0>)
# 3154.8
# prediction for price -- tensor(1.2159, grad_fn=<DivBackward0>)
# Progress: [######----] 55.1% 2930.7
# prediction for price -- tensor(1.1711, grad_fn=<DivBackward0>)
# 2923.9
# prediction for price -- tensor(1.1731, grad_fn=<DivBackward0>)
# 3060.1
# prediction for price -- tensor(1.0271, grad_fn=<DivBackward0>)
# 2925.2
# prediction for price -- tensor(0.8683, grad_fn=<DivBackward0>)
# 2805.6
# prediction for price -- tensor(0.8862, grad_fn=<DivBackward0>)
# 2850.5
# prediction for price -- tensor(0.8969, grad_fn=<DivBackward0>)
# 3000.9
# prediction for price -- tensor(0.8768, grad_fn=<DivBackward0>)
# 3311.4
# prediction for price -- tensor(0.8538, grad_fn=<DivBackward0>)
# 3389.5
# prediction for price -- tensor(0.8387, grad_fn=<DivBackward0>)
# 3419.2
# prediction for price -- tensor(0.9061, grad_fn=<DivBackward0>)
# 3386.5
# prediction for price -- tensor(0.8798, grad_fn=<DivBackward0>)
# 3517.0
# prediction for price -- tensor(0.8628, grad_fn=<DivBackward0>)
# 3576.3
# prediction for price -- tensor(0.8456, grad_fn=<DivBackward0>)
# 3588.3
# prediction for price -- tensor(0.8869, grad_fn=<DivBackward0>)
# 3563.6
# prediction for price -- tensor(1.0042, grad_fn=<DivBackward0>)
# 3573.3
# prediction for price -- tensor(1.0596, grad_fn=<DivBackward0>)
# 3414.3
# prediction for price -- tensor(1.1382, grad_fn=<DivBackward0>)
# 3543.7
# prediction for price -- tensor(1.1862, grad_fn=<DivBackward0>)
# 3490.8
# prediction for price -- tensor(1.2288, grad_fn=<DivBackward0>)
# 3607.9
# prediction for price -- tensor(1.0932, grad_fn=<DivBackward0>)
# 3791.7
# prediction for price -- tensor(1.0142, grad_fn=<DivBackward0>)
# 3870.2
# prediction for price -- tensor(0.9992, grad_fn=<DivBackward0>)
# 3829.6
# prediction for price -- tensor(0.9757, grad_fn=<DivBackward0>)
# 3847.1
# prediction for price -- tensor(1.0108, grad_fn=<DivBackward0>)
# 3745.2
# prediction for price -- tensor(0.9606, grad_fn=<DivBackward0>)
# 3877.9
# prediction for price -- tensor(0.9202, grad_fn=<DivBackward0>)
# 4163.6
# prediction for price -- tensor(1.0101, grad_fn=<DivBackward0>)
# 4053.7
# prediction for price -- tensor(0.9304, grad_fn=<DivBackward0>)
# 3971.4
# prediction for price -- tensor(1.0598, grad_fn=<DivBackward0>)
# 4168.1
# prediction for price -- tensor(0.9335, grad_fn=<DivBackward0>)
# 4082.4
# prediction for price -- tensor(1.0131, grad_fn=<DivBackward0>)
# 4222.4
# prediction for price -- tensor(0.9721, grad_fn=<DivBackward0>)
# 4131.4
# prediction for price -- tensor(0.9928, grad_fn=<DivBackward0>)
# 3923.2
# prediction for price -- tensor(0.9982, grad_fn=<DivBackward0>)
# 4287.5
# prediction for price -- tensor(0.9781, grad_fn=<DivBackward0>)
# 4420.7
# prediction for price -- tensor(0.9871, grad_fn=<DivBackward0>)
# 4324.1
# prediction for price -- tensor(0.9806, grad_fn=<DivBackward0>)
# 4289.9
# prediction for price -- tensor(0.9816, grad_fn=<DivBackward0>)
# 4322.6
# prediction for price -- tensor(0.9840, grad_fn=<DivBackward0>)
# 4594.2
# prediction for price -- tensor(0.9732, grad_fn=<DivBackward0>)
# 4605.7
# prediction for price -- tensor(0.9749, grad_fn=<DivBackward0>)
# 4535.7
# prediction for price -- tensor(0.9739, grad_fn=<DivBackward0>)
# 4478.9
# prediction for price -- tensor(0.9774, grad_fn=<DivBackward0>)
# 4522.4
# prediction for price -- tensor(0.9770, grad_fn=<DivBackward0>)
# 4617.5
# prediction for price -- tensor(0.9739, grad_fn=<DivBackward0>)
# 4811.3
# prediction for price -- tensor(0.9668, grad_fn=<DivBackward0>)
# 4732.8
# prediction for price -- tensor(0.9678, grad_fn=<DivBackward0>)
# 4631.9
# prediction for price -- tensor(0.9665, grad_fn=<DivBackward0>)
# 4720.8
# prediction for price -- tensor(0.9653, grad_fn=<DivBackward0>)
# 4667.0
# prediction for price -- tensor(0.9650, grad_fn=<DivBackward0>)
# 4644.7
# prediction for price -- tensor(0.9581, grad_fn=<DivBackward0>)
# 4627.2
# prediction for price -- tensor(0.9559, grad_fn=<DivBackward0>)
# 4562.9
# prediction for price -- tensor(0.9533, grad_fn=<DivBackward0>)
# 4210.7
# prediction for price -- tensor(0.9527, grad_fn=<DivBackward0>)
# 4289.7
# prediction for price -- tensor(0.9564, grad_fn=<DivBackward0>)
# 3997.0
# prediction for price -- tensor(0.9764, grad_fn=<DivBackward0>)
# 4297.9
# prediction for price -- tensor(0.9585, grad_fn=<DivBackward0>)
# 4416.2
# prediction for price -- tensor(1.0685, grad_fn=<DivBackward0>)
# 4262.3
# prediction for price -- tensor(1.0770, grad_fn=<DivBackward0>)
# 4089.0
# prediction for price -- tensor(1.0801, grad_fn=<DivBackward0>)
# 4342.2
# prediction for price -- tensor(1.1151, grad_fn=<DivBackward0>)
# 4270.6
# prediction for price -- tensor(1.1778, grad_fn=<DivBackward0>)
# 4526.0
# prediction for price -- tensor(1.1718, grad_fn=<DivBackward0>)
# 4042.6
# prediction for price -- tensor(1.2622, grad_fn=<DivBackward0>)
# 4097.4
# prediction for price -- tensor(0.9873, grad_fn=<DivBackward0>)
# 4299.2
# prediction for price -- tensor(1.1073, grad_fn=<DivBackward0>)
# 4448.2
# prediction for price -- tensor(1.0868, grad_fn=<DivBackward0>)
# 4634.4
# prediction for price -- tensor(0.9136, grad_fn=<DivBackward0>)
# 4586.4
# prediction for price -- tensor(1.1032, grad_fn=<DivBackward0>)
# 4515.0
# prediction for price -- tensor(0.8235, grad_fn=<DivBackward0>)
# 4215.3
# prediction for price -- tensor(1.2101, grad_fn=<DivBackward0>)
# 4125.1
# prediction for price -- tensor(1.2679, grad_fn=<DivBackward0>)
# 4201.9
# prediction for price -- tensor(0.9139, grad_fn=<DivBackward0>)
# 4354.9
# prediction for price -- tensor(0.9747, grad_fn=<DivBackward0>)
# 4309.0
# prediction for price -- tensor(1.1380, grad_fn=<DivBackward0>)
# 4441.8
# prediction for price -- tensor(1.1288, grad_fn=<DivBackward0>)
# 4105.1
# prediction for price -- tensor(1.0116, grad_fn=<DivBackward0>)
# 3901.1
# prediction for price -- tensor(1.0194, grad_fn=<DivBackward0>)
# 4094.0
# prediction for price -- tensor(1.0212, grad_fn=<DivBackward0>)
# 4133.6
# prediction for price -- tensor(0.9585, grad_fn=<DivBackward0>)
# 3784.0
# prediction for price -- tensor(0.9919, grad_fn=<DivBackward0>)
# 3861.0
# prediction for price -- tensor(0.9813, grad_fn=<DivBackward0>)
# 4020.6
# prediction for price -- tensor(0.9099, grad_fn=<DivBackward0>)
# 3958.8
# prediction for price -- tensor(0.8528, grad_fn=<DivBackward0>)
# 3875.2
# prediction for price -- tensor(0.8650, grad_fn=<DivBackward0>)
# 3962.1
# prediction for price -- tensor(0.8377, grad_fn=<DivBackward0>)
# 3924.4
# prediction for price -- tensor(0.8632, grad_fn=<DivBackward0>)
# 3944.5
# prediction for price -- tensor(0.8362, grad_fn=<DivBackward0>)
# 4017.2
# prediction for price -- tensor(0.8642, grad_fn=<DivBackward0>)
# 3981.2
# prediction for price -- tensor(0.8637, grad_fn=<DivBackward0>)
# 4112.9
# prediction for price -- tensor(0.8625, grad_fn=<DivBackward0>)
# 4046.9
# prediction for price -- tensor(0.8634, grad_fn=<DivBackward0>)
# 4098.4
# prediction for price -- tensor(0.8602, grad_fn=<DivBackward0>)
# 4064.9
# prediction for price -- tensor(0.8610, grad_fn=<DivBackward0>)
# 4039.0
# prediction for price -- tensor(0.8694, grad_fn=<DivBackward0>)
# 3793.5
# prediction for price -- tensor(0.8768, grad_fn=<DivBackward0>)
# 3628.2
# prediction for price -- tensor(0.8670, grad_fn=<DivBackward0>)
# 3709.9
# prediction for price -- tensor(0.8544, grad_fn=<DivBackward0>)
# 3673.9
# prediction for price -- tensor(0.8558, grad_fn=<DivBackward0>)
# 3766.3
# prediction for price -- tensor(0.8523, grad_fn=<DivBackward0>)
# Progress: [########--] 82.64% 3829.3
# prediction for price -- tensor(0.8915, grad_fn=<DivBackward0>)
# 3765.0
# prediction for price -- tensor(0.8680, grad_fn=<DivBackward0>)
# 3785.3
# prediction for price -- tensor(0.8630, grad_fn=<DivBackward0>)
# 3536.4
# prediction for price -- tensor(0.8642, grad_fn=<DivBackward0>)
# 3405.7
# prediction for price -- tensor(0.8666, grad_fn=<DivBackward0>)
# 3197.0
# prediction for price -- tensor(0.9149, grad_fn=<DivBackward0>)
# 3080.2
# prediction for price -- tensor(0.8841, grad_fn=<DivBackward0>)
# 3150.0
# prediction for price -- tensor(0.9671, grad_fn=<DivBackward0>)
# 3083.8
# prediction for price -- tensor(0.9773, grad_fn=<DivBackward0>)
# 3241.7
# prediction for price -- tensor(1.0325, grad_fn=<DivBackward0>)
# 3373.4
# prediction for price -- tensor(0.9763, grad_fn=<DivBackward0>)
# 3242.0
# prediction for price -- tensor(1.0439, grad_fn=<DivBackward0>)
# 3310.0
# prediction for price -- tensor(1.0384, grad_fn=<DivBackward0>)
# 3327.9
# prediction for price -- tensor(1.0298, grad_fn=<DivBackward0>)
# 3348.8
# prediction for price -- tensor(1.0259, grad_fn=<DivBackward0>)
# 3210.4
# prediction for price -- tensor(1.0127, grad_fn=<DivBackward0>)
# 3161.6
# prediction for price -- tensor(0.9933, grad_fn=<DivBackward0>)
# 3084.4
# prediction for price -- tensor(1.0227, grad_fn=<DivBackward0>)
# 3001.1
# prediction for price -- tensor(1.0094, grad_fn=<DivBackward0>)
# 2568.7
# prediction for price -- tensor(1.0616, grad_fn=<DivBackward0>)
# 2411.9
# prediction for price -- tensor(1.0106, grad_fn=<DivBackward0>)
# 2540.9
# prediction for price -- tensor(1.0918, grad_fn=<DivBackward0>)
# 2441.1
# prediction for price -- tensor(1.0591, grad_fn=<DivBackward0>)
# 2459.9
# prediction for price -- tensor(1.0728, grad_fn=<DivBackward0>)
# 2463.6
# prediction for price -- tensor(1.0685, grad_fn=<DivBackward0>)
# 2426.3
# prediction for price -- tensor(1.0590, grad_fn=<DivBackward0>)
# 2547.2
# prediction for price -- tensor(1.0259, grad_fn=<DivBackward0>)
# 2602.7
# prediction for price -- tensor(1.0124, grad_fn=<DivBackward0>)
# 2603.9
# prediction for price -- tensor(1.0150, grad_fn=<DivBackward0>)
# 2687.9
# prediction for price -- tensor(1.0148, grad_fn=<DivBackward0>)
# 2789.3
# prediction for price -- tensor(1.0188, grad_fn=<DivBackward0>)
# 2682.3
# prediction for price -- tensor(1.0353, grad_fn=<DivBackward0>)
# 2697.9
# prediction for price -- tensor(1.0213, grad_fn=<DivBackward0>)
# 2997.4
# prediction for price -- tensor(1.0079, grad_fn=<DivBackward0>)
# 3014.9
# prediction for price -- tensor(0.8747, grad_fn=<DivBackward0>)
# 3058.3
# prediction for price -- tensor(0.8603, grad_fn=<DivBackward0>)
# 3141.7
# prediction for price -- tensor(0.8555, grad_fn=<DivBackward0>)
# 3119.6
# prediction for price -- tensor(0.8477, grad_fn=<DivBackward0>)
# 3245.9
# prediction for price -- tensor(0.8423, grad_fn=<DivBackward0>)
# 3074.1
# prediction for price -- tensor(0.8464, grad_fn=<DivBackward0>)
# 2929.5
# prediction for price -- tensor(0.8492, grad_fn=<DivBackward0>)
# 2919.8
# prediction for price -- tensor(0.8562, grad_fn=<DivBackward0>)
# 2872.3
# prediction for price -- tensor(0.8649, grad_fn=<DivBackward0>)
# 2931.4
# prediction for price -- tensor(0.8734, grad_fn=<DivBackward0>)
# 3186.2
# prediction for price -- tensor(0.8744, grad_fn=<DivBackward0>)
# 3124.1
# prediction for price -- tensor(0.8350, grad_fn=<DivBackward0>)
# 2893.5
# prediction for price -- tensor(0.9125, grad_fn=<DivBackward0>)
# 2781.0
# prediction for price -- tensor(0.9225, grad_fn=<DivBackward0>)
# 2764.3
# prediction for price -- tensor(0.9804, grad_fn=<DivBackward0>)
# 2621.5
# prediction for price -- tensor(0.9674, grad_fn=<DivBackward0>)
# 2569.6
# prediction for price -- tensor(1.1287, grad_fn=<DivBackward0>)
# 2637.6
# prediction for price -- tensor(0.9951, grad_fn=<DivBackward0>)
# 2580.5
# prediction for price -- tensor(0.9382, grad_fn=<DivBackward0>)
# 2598.2
# prediction for price -- tensor(0.8741, grad_fn=<DivBackward0>)
# 2768.3
# prediction for price -- tensor(0.8407, grad_fn=<DivBackward0>)
# 2780.4
# prediction for price -- tensor(0.8606, grad_fn=<DivBackward0>)
# 2617.8
# prediction for price -- tensor(0.8530, grad_fn=<DivBackward0>)
# 2924.0
# prediction for price -- tensor(0.8383, grad_fn=<DivBackward0>)
# 2978.3
# prediction for price -- tensor(0.8541, grad_fn=<DivBackward0>)
# 2948.3
# prediction for price -- tensor(0.8833, grad_fn=<DivBackward0>)
# 2834.1
# prediction for price -- tensor(0.8794, grad_fn=<DivBackward0>)
# 2622.4
# prediction for price -- tensor(0.8604, grad_fn=<DivBackward0>)
# 2665.0
# prediction for price -- tensor(0.8609, grad_fn=<DivBackward0>)
# Progress: [##########] 100% Done...
#
# Historical Dataframes:
# Account History:
#            USD    ETH          time  Account Value (USD)
# 0    10000.000  0.000  1.615162e+09           10000.0000
# 1    10000.000  0.000  1.615162e+09           10000.0000
# 2    10000.000  0.000  1.615248e+09           10000.0000
# 3     7591.752  1.334  1.615334e+09            9989.2168
# 4     7226.212  1.533  1.615421e+09           10028.0761
# ..         ...    ...           ...                  ...
# 359  18229.232  0.535  1.646093e+09           19822.6225
# 360  18405.422  0.475  1.646179e+09           19805.8645
# 361  18546.559  0.425  1.646266e+09           19751.0515
# 362  18677.154  0.375  1.646352e+09           19660.5540
# 363  18809.871  0.325  1.646438e+09           19675.9960
#
# [364 rows x 4 columns]
# Account Returns:
#              time     value
# 0    1.615162e+09       NaN
# 1    1.615248e+09  0.000000
# 2    1.615334e+09  0.000000
# 3    1.615421e+09 -0.001078
# 4    1.615507e+09  0.003890
# ..            ...       ...
# 358  1.646093e+09  0.011437
# 359  1.646179e+09  0.001661
# 360  1.646266e+09 -0.000845
# 361  1.646352e+09 -0.002768
# 362  1.646438e+09 -0.004582
#
# [363 rows x 2 columns]
# Resampled Account Value:
#              time       value
# 0    1.615162e+09  10000.0000
# 1    1.615248e+09  10000.0000
# 2    1.615334e+09  10000.0000
# 3    1.615421e+09   9989.2168
# 4    1.615507e+09  10028.0761
# ..            ...         ...
# 358  1.646093e+09  19789.7590
# 359  1.646179e+09  19822.6225
# 360  1.646266e+09  19805.8645
# 361  1.646352e+09  19751.0515
# 362  1.646438e+09  19660.5540
#
# [363 rows x 2 columns]
# Blankly Metrics:
# Compound Annual Growth Rate (%):   98.0%
# Cumulative Returns (%):            97.0%
# Max Drawdown (%):                  20.0%
# Variance (%):                      12.59%
# Sortino Ratio:                     2.17
# Sharpe Ratio:                      1.5
# Calmar Ratio:                      2.69
# Volatility:                        0.35
# Value-at-Risk:                     395.43
# Conditional Value-at-Risk:         10.0
# Risk Free Return Rate:             0.0
# Resampled Time:                    86400.0

# %% [markdown]
# Here, we test our model! We start with $10,000 and connect to FTX's API through Blankly. After creating a Blankly strategy and adding our price event, we can run and see the results. We find a CAGR of 98% -- very good, along with a Sharpe Ratio of 1.5 and a Sortino Ratio of 2.17, both also considered strong. There are many ways we could improve this strategy -- deepen the machine learning model, pull more/better input data, or better choose amounts to buy/sell, but this is a very strong start, and Blankly's package makes it very easy to edit and test this model.
